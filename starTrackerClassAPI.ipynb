# %%
from importlib import reload 
import simStarTrackerImage 

import numpy as np

# %%
reload(simStarTrackerImage)
# Out:
# <module 'simStarTrackerImage' from '/Users/chyan/PythonCode/Instrument/simStarTracker/simStarTrackerImage.py'>

# %%
st=simStarTrackerImage.SimStarTrackerImage(1096, 2048)
st.ra=249.534279 
st.dec=2.938149 
st.rot=120.916866

st.exptime = 0.1

# %%
#st.buildWCS(wcsFile='./ObsImage/Cam5_Altair_1.0.wcs')

st.buildWCS()
catalog = './Catalog/gsc.all'
stars=st.readStarCatalog(catalog)
# Out:
# 2021-06-29T13:56:30.559 20 simStarTracker [simStarTrackerImage.py:59] Buiding WCS from empty
# 2021-06-29T13:56:30.560 20 simStarTracker [simStarTrackerImage.py:82] Rotate WCS by 120.916866 degrees.
# 2021-06-29T13:56:31.464 20 simStarTracker [simStarTrackerImage.py:146] Star catalog is ready

# %%
stars
# Out:
#                ra       dec  Vmag source            x            y  ABmag  \
# 3931   242.460325 -3.466747  5.55      T  1050.382858   870.796806   5.57
# 3937   243.190387 -1.721943  7.46      T   946.084052   856.247352   7.48
# 3938   243.235604 -4.220914  6.27      T  1064.127773   928.946569   6.29
# 3940   243.310851 -1.402499  7.77      T   927.457108   852.981096   7.79
# 3941   243.356386 -4.051646  6.98      T  1052.521060   929.867828   7.00
# ...           ...       ...   ...    ...          ...          ...    ...
# 38725  256.320417  0.702500  6.01      B   461.231601  1405.817958   6.03
# 38726  261.657917 -5.086667  4.54      B   584.502832  1833.095972   4.56
# 38727  262.599167 -1.062500  5.31      B   363.362214  1760.722543   5.33
# 38728  267.328750  1.961111  6.47      B    74.018693  1908.716204   6.49
# 38730  268.147500  1.305000  5.95      B    80.229830  1970.841541   5.97
#
#               Jy       theta          rho      Nphoton
# ...

# %%
st.ra=249.606454
st.dec=3.089867
st.rot=120.923687

st.exptime = 0.1

# %%
st.buildWCS()
catalog = './Catalog/gsc.all'
stars=st.readStarCatalog(catalog)
# Out:
# 2021-06-29T14:04:13.166 20 simStarTracker [simStarTrackerImage.py:59] Buiding WCS from empty
# 2021-06-29T14:04:13.168 20 simStarTracker [simStarTrackerImage.py:82] Rotate WCS by 120.923687 degrees.
# 2021-06-29T14:04:14.051 20 simStarTracker [simStarTrackerImage.py:146] Star catalog is ready

# %%
stars
# Out:
#                ra       dec  Vmag source            x            y  ABmag  \
# 3931   242.460325 -3.466747  5.55      T  1059.743591   871.633033   5.57
# 3937   243.190387 -1.721943  7.46      T   955.357826   857.087903   7.48
# 3938   243.235604 -4.220914  6.27      T  1073.501171   929.808548   6.29
# 3940   243.310851 -1.402499  7.77      T   936.717533   853.822502   7.79
# 3941   243.356386 -4.051646  6.98      T  1061.883382   930.730643   7.00
# ...           ...       ...   ...    ...          ...          ...    ...
# 38725  256.320417  0.702500  6.01      B   470.334467  1406.677112   6.03
# 38726  261.657917 -5.086667  4.54      B   593.584214  1834.067876   4.56
# 38727  262.599167 -1.062500  5.31      B   372.461183  1761.517703   5.33
# 38728  267.328750  1.961111  6.47      B    83.259810  1909.253795   6.49
# 38730  268.147500  1.305000  5.95      B    89.460166  1971.367974   5.97
#
#               Jy       theta          rho      Nphoton
# ...
